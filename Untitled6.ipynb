# %%
from bs4 import BeautifulSoup
import requests

# %%
url="https://ec.geo-online.co.jp/shop/goods/search.aspx?search.x=0&keyword=&goods_code=&store=&tree=15&genre_tree=&capacity=&price=&flg="

# %%
headers = {"Accept-Language": "en-US,en;q=0.5"}
r=requests.get(url,cookies= {'googletrans': '/es/en'}, lang='es-eu')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-b8d86e5c8978> in <module>
#       1 headers = {"Accept-Language": "en-US,en;q=0.5"}
# ----> 2 r=requests.get(url,cookies= {'googletrans': '/es/en'}, lang='es-eu')
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# TypeError: request() got an unexpected keyword argument 'lang'

# %%
htmlcontent=r.content
soup=BeautifulSoup(htmlcontent,'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN"
#     "http://www.w3.org/TR/html4/loose.dtd">
# <html lang="ja">
#  <head>
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-N9XBMJ4');
#   </script>
#   <!-- End Google Tag Manager -->
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    ゲオ公式通販サイト/ゲオオンラインストア
#   </title>
#   <meta content="中古ゲーム・スマホ・携帯・タブレット・中古パソコン・中古家電・iPod・WALKMANの在庫を豊富にそろえてます！「赤ロム永久保証」「家電6か月保証」更に2000円以上購入で送料無料です。" name="description"/>
#   <meta content="ゲオの公式通販サイト「ゲオオンラインストア」！中古ゲーム・スマホ・携帯・タブレットの在庫を豊富にそろえてます！「赤ロム永久保証」更に2000円以上購入で送料無料です。" name="Keywords" og:title"=""/>
# ...
