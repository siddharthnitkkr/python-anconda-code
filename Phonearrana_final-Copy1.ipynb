# %%
from bs4 import BeautifulSoup
import requests
import urllib

# %%
device=list()
date=list()
display=list()
camera=list()
storage=list()
ram=list()
price=list()
battery=list()
operating_system=list()
url=list()

# %%
def find_all_page_links(Url,pagelinks):
    
    htmlContent = urllib.request.urlopen(Url).read()
    soup=BeautifulSoup(htmlContent,'html.parser') 
    nav=soup.find('nav',attrs={'aria-label':'navigation'})
    links=nav.find_all('a')
    
    for link in links:
        if(link.get('href')!='#'):
            pagelinks.append(link.get('href'))

# %%
def get_device_data(Url):
    print(Url)
    htmlContent = urllib.request.urlopen(Url).read()
    soup=BeautifulSoup(htmlContent,'html.parser')
    #dev=soup.find('li',attrs={'class':'active'}).text
    
    div_data=soup.find('section',attrs={'class':'phone__section phone__section_widget_quickSpecs'})
    if div_data != None:
        links=div_data.find_all('a')
        dev=soup.find('li',attrs={'class':'active'}).text
        dat=""
        dis=""
        cam=""
        ra=""
        sto=""
        bat=""
        os=""
        pr=""
        
        


        '''
        if len(links)>=5:

            dat=links[0].find('p').text
            if 'Mp' in links[2].find('p').text.replace('\n',' '):
                cam=links[2].find('p').text.replace('\n',' ')
            if 'Ram' in links[3].find('p').text.replace('\n',' '):
                ra=links[3].find('p').text.replace('\n',' ')
            if 'GB' in  links[4].find('p').text.replace('\n',' '):
                sto=links[4].find('p').text.replace('\n',' ')
                
                
            tbody_data=soup.find_all('tbody')

            j=0
            for data in tbody_data:

                if 'Differences from the main variant:' not in data.text and 'Price' in data.text:
                    pr=data.text.replace('\n',' ')
                elif 'Differences from the main variant:' in data.text:
                    alt.append(data.text.replace('\n',' '))

         '''
        for li in links:
            temp=li.text.replace('\n','')
            if "Released" in temp:
                dat=li.find('p').text.replace('\n','')
            elif "Display" in temp:
                dis=li.find('p').text.replace('\n','')
            elif "Camera" in temp:
                cam=li.find('p').text.replace('\n','')
            elif "Hardware" in temp:
                ra=li.find('p').text.replace('\n','')
            elif "Storage" in temp:
                sto=li.find('p').text.replace('\n','')
            elif "Battery" in temp:
                bat=li.find('p').text.replace('\n','')
            elif "OS" in temp:
                op=li.find('p').text.replace('\n','')
                
        
        '''
        te=soup.find_all('section',attrs={'class':"page__section page__section_specs"})
        for t in te:
            if 'Buyers information' in  t.text and 'Price' in t.text:
                tb=t.find_all('tbody')
                for tbb in tb:
                    if "Price" in tbb.text:
                        pr=tbb.text
        '''
        te=soup.find_all('table')
        for t in te:
             if 'Buyers information' in  t.text and 'Price' in t.text:    
                     pr=t.text
                        
                        
        device.append(dev)               
        date.append(dat)
        display.append(dis)
        camera.append(cam)
        ram.append(ra)
        storage.append(sto)
        battery.append(bat)
        price.append(pr)
        operating_system.append(os)
        url.append(Url)
        
        
        at=soup.find_all('div',attrs={'class':"widgetAlternativeVariants"})
        for a in at:
            dev=""
            
            dis=""
            cam=""
            ra=""
            sto=""
            bat=""
            
            pr=""
           
            dev=a.find('h2').text.replace('\n','')
            print(dev)
            tb=a.find_all('td')
            for i in tb:
                print(i.text)
                if 'GB' in i.text:
                    sto=i.text.replace('\n','')
                if '$' in i.text:
                    pr=i.text.replace('\n','')
                
            device.append(dev)               
            date.append(dat)
            display.append(dis)
            camera.append(cam)
            ram.append(ra)
            storage.append(sto)
            battery.append(bat)
            
            price.append(pr)
            operating_system.append(os)
            url.append(Url)

# %%
def find_all_device_links(Url):
    
    htmlContent = urllib.request.urlopen(Url).read()
    soup=BeautifulSoup(htmlContent,'html.parser') 
    div_data=soup.find('div',attrs={'class':'stream block'})
    links=div_data.find_all('a')
    device_links=set()
    for link in links:
        if(link.get('href')!='#'):
            device_links.add(link.get('href'))
    return device_links

# %%
Url="https://www.phonearena.com/phones/manufacturers/apple"

# %%
visitedlinks=set()
pagelinks=list()

# %%
pagelinks.append(Url)
for link in pagelinks: 
    Url=link
    if link not in visitedlinks:             
        
        device_links=find_all_device_links(link)
        print(device_links)
        for li in device_links:
            if li not in visitedlinks:
                
                get_device_data(li)
                visitedlinks.add(li)
        
        find_all_page_links(link,pagelinks)
        visitedlinks.add(link)
# Out:
# {'https://www.phonearena.com/phones/Apple-iPhone-11-Pro-Max_id11179', 'https://www.phonearena.com/phones/Apple-iPhone-6s_id9501', 'https://www.phonearena.com/phones/Apple-iPhone-7-Plus_id9816', 'https://www.phonearena.com/phones/Apple-iPad-Pro-10.5-inch_id10561', 'https://www.phonearena.com/phones/Apple-iPhone-XS-Max_id10767', 'https://www.phonearena.com/phones/Apple-iPhone-SE_id10001', 'https://www.phonearena.com/phones/Apple-iPhone-11-Pro_id11239', 'https://www.phonearena.com/phones/Apple-iPhone-12_id11333', 'https://www.phonearena.com/phones/Apple-iPhone-X_id10414', 'https://www.phonearena.com/phones/Apple-iPhone-12-Pro_id11294', 'https://www.phonearena.com/phones/Apple-iPod-Touch-2019_id11186', 'https://www.phonearena.com/phones/Apple-iPad-9.7-inch_id10472', 'https://www.phonearena.com/phones/Apple-iPad-Pro-9.7-inch_id10011', 'https://www.phonearena.com/phones/Apple-iPhone-XR_id10765', 'https://www.phonearena.com/phones/Apple-Watch-Series-5-40mm_id11443', 'https://www.phonearena.com/phones/Apple-iPhone-6s-Plus_id9502', 'https://www.phonearena.com/phones/Apple-iPad-Pro-12.9-inch-2018_id11033', 'https://www.phonearena.com/phones/Apple-iPad-Pro_id9640', 'https://www.phonearena.com/phones/Apple-iPad-mini-2019_id11157', 'https://www.phonearena.com/phones/Apple-iPad-Pro-11-inch-2020_id11380', 'https://www.phonearena.com/phones/Apple-iPhone-12-Max_id11417', 'https://www.phonearena.com/phones/Apple-iPad-Pro-12.9-inch_id10562', 'https://www.phonearena.com/phones/Apple-iPhone-SE-2020_id10750', 'https://www.phonearena.com/phones/Apple-iPhone-12-Pro-Max_id11331', 'https://www.phonearena.com/phones/Apple-iPad-Air-2019_id11156', 'https://www.phonearena.com/phones/Apple-iPhone-11_id11175', 'https://www.phonearena.com/phones/Apple-iPhone-8_id10408', 'https://www.phonearena.com/phones/Apple-iPhone-8-Plus_id10411', 'https://www.phonearena.com/phones/Apple-iPhone-7_id9815', 'https://www.phonearena.com/phones/Apple-iPad-mini-4_id9641', 'https://www.phonearena.com/phones/Apple-iPad-Pro-11-inch_id11034', 'https://www.phonearena.com/phones/Apple-iPad-10.2-inch_id11247', 'https://www.phonearena.com/phones/Apple-iPad-9.7-inch-2018_id10852', 'https://www.phonearena.com/phones/Apple-iPhone-XS_id10766', 'https://www.phonearena.com/phones/Apple-iPad-Pro-12.9-inch-2020_id11312', 'https://www.phonearena.com/phones/Apple-Watch-Series-5-44mm_id11451'}
# https://www.phonearena.com/phones/Apple-iPhone-11-Pro-Max_id11179
#             Apple iPhone 11 Pro Max
# 512GB
# $ 1449
#             Apple iPhone 11 Pro Max
# 256GB
# $ 1249
# https://www.phonearena.com/phones/Apple-iPhone-6s_id9501
#             Apple iPhone 6s
# 16GB
# $ 649 / € 739
#             Apple iPhone 6s
# 64GB
# $ 749 / € 849
#             Apple iPhone 6s
# Bands 1(2100), 2(1900), 3(1800), 4(AWS-1), 5(850), 7(2600), 8(900), 12(700 a), 13(700 c), 17(700 b), 18(800 Lower), 19(800 Upper), 20(800 DD), 25(1900+), 26(850+), 28(700 APT), 29(700 d), 30(2300 WCS)
#             Apple iPhone 6s
# 32GB
# https://www.phonearena.com/phones/Apple-iPhone-7-Plus_id9816
#             Apple iPhone 7 Plus
# 32GB
# $ 769
#             Apple iPhone 7 Plus
# 128GB
# $ 869
#             Apple iPhone 7 Plus
# 850, 900, 1700/2100, 1900, 2100 MHz
# https://www.phonearena.com/phones/Apple-iPad-Pro-10.5-inch_id10561
#             Apple iPad Pro 10.5-inch 256GB
# 256GB
# $ 879
#             Apple iPad Pro 10.5-inch 64GB
# 64GB
# $ 779
#             Apple iPad Pro 10.5-inch Wi-Fi
# 16.54 oz (469.0 g)
# $ 949
#             Apple iPad Pro 10.5-inch Wi-Fi 256GB
# 256GB
# 16.54 oz (469.0 g)
# $ 749
#             Apple iPad Pro 10.5-inch Wi-Fi 64GB
# 64GB
# 16.54 oz (469.0 g)
# $ 649
# https://www.phonearena.com/phones/Apple-iPhone-XS-Max_id10767
#             Apple iPhone XS Max
# 512GB
# $ 1449
#             Apple iPhone XS Max
# 256GB
# $ 1249
# https://www.phonearena.com/phones/Apple-iPhone-SE_id10001
#             Apple iPhone SE
# 16GB
# $ 399
#             Apple iPhone SE
# 32GB
# $ 399
#             Apple iPhone SE
# 64GB
# $ 499
#             Apple iPhone SE
# Bands 1(2100), 2(1900), 3(1800), 4(AWS-1), 5(850), 7(2600), 8(900), 12(700 a), 17(700 b), 18(800 Lower), 19(800 Upper), 20(800 DD), 25(1900+), 26(850+), 28(700 APT)
# https://www.phonearena.com/phones/Apple-iPhone-11-Pro_id11239
#             Apple iPhone 11 Pro
# 512GB
# $ 1349
#             Apple iPhone 11 Pro
# 256GB
# $ 1149
# https://www.phonearena.com/phones/Apple-iPhone-12_id11333
# https://www.phonearena.com/phones/Apple-iPhone-X_id10414
#             Apple iPhone X
# 64GB
# $ 999
#             Apple iPhone X
# https://www.phonearena.com/phones/Apple-iPhone-12-Pro_id11294
# https://www.phonearena.com/phones/Apple-iPod-Touch-2019_id11186
#             Apple iPod Touch (2019)
# 32GB
# $ 199
#             Apple iPod Touch (2019)
# 128GB
# $ 299
# https://www.phonearena.com/phones/Apple-iPad-9.7-inch_id10472
#             Apple iPad 9.7-inch 32GB
# 32GB
# $ 459
#             Apple iPad 9.7-inch 32GB
# 32GB
# 16.54 oz (469.0 g)
# $ 329
#             Apple iPad 9.7-inch 128GB
# 128GB
# 16.54 oz (469.0 g)
# $ 429
# https://www.phonearena.com/phones/Apple-iPad-Pro-9.7-inch_id10011
#             Apple iPad Pro 9.7-inch Wi-Fi 32GB
# 32GB
# $ 599
# Mar 21, 2016
#             Apple iPad Pro 9.7-inch Wi-Fi 128GB
# 128GB
# $ 749
#             Apple iPad Pro 9.7-inch Wi-Fi 256GB
# 256GB
# $ 899
#             Apple iPad Pro 9.7-inch 32GB
# 32GB
# $ 729
#             Apple iPad Pro 9.7-inch 128GB
# 128GB
# $ 879
# https://www.phonearena.com/phones/Apple-iPhone-XR_id10765
#             Apple iPhone XR
# 256GB
# $ 899
#             Apple iPhone XR
# 128GB
# $ 799
# https://www.phonearena.com/phones/Apple-Watch-Series-5-40mm_id11443
#             Apple Watch Series 5 (40mm)
# Aluminum: Silver, Space gray, Gold
# $ 399
# https://www.phonearena.com/phones/Apple-iPhone-6s-Plus_id9502
#             Apple iPhone 6s Plus
# 16GB
# $ 749 / € 849
#             Apple iPhone 6s Plus
# 64GB
# $ 849 / € 959
#             Apple iPhone 6s Plus
# Bands 1(2100), 2(1900), 3(1800), 4(AWS-1), 5(850), 7(2600), 8(900), 12(700 a), 13(700 c), 17(700 b), 18(800 Lower), 19(800 Upper), 20(800 DD), 25(1900+), 26(850+), 28(700 APT), 29(700 d), 30(2300 WCS)
#             Apple iPhone 6s Plus
# 32GB
# https://www.phonearena.com/phones/Apple-iPad-Pro-12.9-inch-2018_id11033
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# ~\anaconda3\lib\http\client.py in _readall_chunked(self)
#     573                     break
# --> 574                 value.append(self._safe_read(chunk_left))
#     575                 self.chunk_left = 0
#
# ~\anaconda3\lib\http\client.py in _safe_read(self, amt)
#     621             if not chunk:
# --> 622                 raise IncompleteRead(b''.join(s), amt)
#     623             s.append(chunk)
#
# IncompleteRead: IncompleteRead(16378 bytes read, 16390 more expected)
#
# During handling of the above exception, another exception occurred:
#
# IncompleteRead                            Traceback (most recent call last)
# <ipython-input-93-4660ccebb7bc> in <module>
#       9             if li not in visitedlinks:
#      10
# ---> 11                 get_device_data(li)
#      12                 visitedlinks.add(li)
#      13
#
# <ipython-input-89-8af039f6b43a> in get_device_data(Url)
#       1 def get_device_data(Url):
#       2     print(Url)
# ----> 3     htmlContent = urllib.request.urlopen(Url).read()
#       4     soup=BeautifulSoup(htmlContent,'html.parser')
#       5     #dev=soup.find('li',attrs={'class':'active'}).text
#
# ~\anaconda3\lib\http\client.py in read(self, amt)
#     462
#     463             if self.chunked:
# --> 464                 return self._readall_chunked()
#     465
#     466             if self.length is None:
#
# ~\anaconda3\lib\http\client.py in _readall_chunked(self)
#     576             return b''.join(value)
#     577         except IncompleteRead:
# --> 578             raise IncompleteRead(b''.join(value))
#     579
#     580     def _readinto_chunked(self, b):
#
# IncompleteRead: IncompleteRead(32096 bytes read)

# %%
len(visitedlinks)

# %%
device

# %%
import pandas as pd
df=pd.DataFrame()
df['device']=device
df['date']=date
df['camera']=camera
df['storage']=storage
df['ram']=ram
df['price']=price
df['url']=url


df.to_excel("apple data from phonearrana2.xlsx")

# %%
len(url)

# %%
storage

# %%
date
