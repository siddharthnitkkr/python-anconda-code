# %%
from bs4 import BeautifulSoup
import requests
import urllib
import pandas as pd

# %%
df=pd.read_excel(r'C:\Users\Siddy\Desktop\document\equiplist 20 aug.xlsx')

# %%
df
# Out:
#            Model ID                          WAREHOUSE_MODEL Manufacturer  \
# 0    M1110000013781                 iPhone 5s 16GB - GENERIC        Apple
# 1    M1110000013775                      iPhone 5s 16GB - AU        Apple
# 2    M1110000013778                  iPhone 5s 16GB - DOCOMO        Apple
# 3    M1110000013772                iPhone 5s 16GB - SOFTBANK        Apple
# 4    M1110000013782                 iPhone 5s 32GB - GENERIC        Apple
# ..              ...                                      ...          ...
# 175  M1110000014381                Xperia XZ1 64GB - GENERIC         Sony
# 176  M1110000014157               Xperia XZ1 SOV36 64GB - AU         Sony
# 177  M1110000013894          Xperia XZ1 SO-01K 64GB - DOCOMO         Sony
# 178  M1110000014106         Xperia XZ1 701SO 64GB - SOFTBANK         Sony
# 179  M1110000013895  Xperia XZ2 Compact SO-05K 64GB - DOCOMO         Sony
#
#          Marketing Name Carrier / Region  \
# ...

# %%
list(df['URL/search KW'])
# Out:
# ['https://ec.geo-online.co.jp/shop/goods/search.aspx?sort=sp&search.x=&tree=154119',
#  'https://ec.geo-online.co.jp/shop/goods/search.aspx?sort=sp&search.x=&tree=151123',
#  'https://ec.geo-online.co.jp/shop/goods/search.aspx?sort=sp&search.x=&tree=15215',
#  'https://ec.geo-online.co.jp/shop/goods/search.aspx?sort=sp&search.x=&tree=153187',
#  'do.',
#  'do.',
#  'do.',
#  'do.',
#  'https://ec.geo-online.co.jp/shop/goods/search.aspx?sort=sp&search.x=&tree=154117',
#  'https://ec.geo-online.co.jp/shop/goods/search.aspx?sort=sp&search.x=&tree=151119',
#  'https://ec.geo-online.co.jp/shop/goods/search.aspx?sort=sp&search.x=&tree=152148',
#  'https://ec.geo-online.co.jp/shop/goods/search.aspx?sort=sp&search.x=&tree=153185',
#  'do.',
#  'do.',
#  'do.',
#  'do.',
#  'do.',
#  'do.',
#  'do.',
#  'do.',
#  'https://ec.geo-online.co.jp/shop/goods/search.aspx?sort=sp&search.x=&tree=154115',
#  'https://ec.geo-online.co.jp/shop/goods/search.aspx?sort=sp&search.x=&tree=151117',
# ...
