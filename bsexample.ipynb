# %%
from bs4 import BeautifulSoup
import requests

# %%
url="https://ec.geo-online.co.jp/shop/goods/search.aspx?search.x=0&keyword=&goods_code=&store=&tree=1510&genre_tree=&capacity=&price=&flg="
r=requests.get(url)

# %%
htmlContent =r.content
print(htmlContent)
# Out:
# b'\r\n<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN"\r\n    "http://www.w3.org/TR/html4/loose.dtd">\r\n<html lang="ja">\r\n<head>\r\n<!-- Google Tag Manager -->\r\n<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\r\nnew Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\r\nj=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\r\n\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\r\n})(window,document,\'script\',\'dataLayer\',\'GTM-N9XBMJ4\');</script>\r\n<!-- End Google Tag Manager -->\r\n\r\n\r\n<meta http-equiv="Content-Type" content="text/html; charset=Shift_JIS">\r\n<title>\x83Q\x83I\x8c\xf6\x8e\xae\x92\xca\x94\xcc\x83T\x83C\x83g/\x83Q\x83I\x83I\x83\x93\x83\x89\x83C\x83\x93\x83X\x83g\x83A</title>\r\n<meta name="description" content="\x92\x86\x8c\xc3\x83Q\x81[\x83\x80\x81E\x83X\x83}\x83z\x81E\x8cg\x91\xd1\x81E\x83^\x83u\x83\x8c\x83b\x83g\x81E\x92\x86\x8c\xc3\x83p\x83\\\
# ...

# %%
soup=BeautifulSoup(htmlContent,'html.parser')
print(soup)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN"
#     "http://www.w3.org/TR/html4/loose.dtd">
#
# <html lang="ja">
# <head>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-N9XBMJ4');</script>
# <!-- End Google Tag Manager -->
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>ゲオ公式通販サイト/ゲオオンラインストア</title>
# <meta content="中古ゲーム・スマホ・携帯・タブレット・中古パソコン・中古家電・iPod・WALKMANの在庫を豊富にそろえてます！「赤ロム永久保証」「家電6か月保証」更に2000円以上購入で送料無料です。" name="description"/>
# <meta content="ゲオの公式通販サイト「ゲオオンラインストア」！中古ゲーム・スマホ・携帯・タブレットの在庫を豊富にそろえてます！「赤ロム永久保証」更に2000円以上購入で送料無料です。" name="Keywords" og:title"=""/>
# ...

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN"
#     "http://www.w3.org/TR/html4/loose.dtd">
#
# <html lang="ja">
# <head>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-N9XBMJ4');</script>
# <!-- End Google Tag Manager -->
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>ゲオ公式通販サイト/ゲオオンラインストア</title>
# <meta content="中古ゲーム・スマホ・携帯・タブレット・中古パソコン・中古家電・iPod・WALKMANの在庫を豊富にそろえてます！「赤ロム永久保証」「家電6か月保証」更に2000円以上購入で送料無料です。" name="description"/>
# <meta content="ゲオの公式通販サイト「ゲオオンラインストア」！中古ゲーム・スマホ・携帯・タブレットの在庫を豊富にそろえてます！「赤ロム永久保証」更に2000円以上購入で送料無料です。" name="Keywords" og:title"=""/>
# ...

# %%
title=soup.title
print(title.getText())
blob=TextBlob("【中古】【安心保証】 au iPhone6s[16G] シルバー")
eng=blob.translate(to="EN")
print(eng)
# Out:
# ゲオ公式通販サイト/ゲオオンラインストア
# [Used] [Security guarantee] au iPhone6s[16G] Silver

# %%
print(title.string)
# Out:
# Free Programming Videos, Courses & More In Hindi
#  - Code With Harry

# %%
print(soup.find_all('p'))
# Out:
# [<p class="lead text-muted">Confused on which course to take? I have got you covered. Browse courses and find out
#             the best course for you. Its free!<br/>Code With Harry is my attempt to teach basics and those coding
#             techniques to people in short time which took me ages to learn.</p>, <p>
# <a class="btn btn-danger my-2" href="/blog">Browse Blog</a>
# <a class="btn btn-success my-2" href="/videos">Browse Video Tutorials</a>
# <a class="btn btn-primary my-2" href="/contact">Contact Me</a>
# </p>, <p class="card-text">Get your programming career started with these free video courses. Source code is
#                     available with all the videos for your better experience</p>, <p class="card-text">Some of the latest coding information compiled as coding articles. Keep your
#                     programming knowledge up to date with our coding articles.</p>, <p class="card-text">Learn programming from our free courses. Examples are available with these
# ...

# %%
print(soup.find_all('a'))
# Out:
# [<a class="navbar-brand" href="/"><img alt="My image" class="brandLogo" src="/static/common/img/photo.png"/></a>, <a class="nav-link" href="/">Home</a>, <a class="nav-link" href="/videos">Videos</a>, <a class="nav-link" href="/blog">Blog</a>, <a class="nav-link" href="/contact">Contact Me</a>, <a class="btn btn-danger my-2" href="/blog">Browse Blog</a>, <a class="btn btn-success my-2" href="/videos">Browse Video Tutorials</a>, <a class="btn btn-primary my-2" href="/contact">Contact Me</a>, <a class="btn btn-primary" href="/videos">Browse Video Courses</a>, <a class="btn btn-primary" href="/blog">Go to Blog</a>, <a class="btn btn-primary" href="/contact">Contact Me</a>, <a href="#">Back to top</a>, <a href="#">Privacy</a>, <a href="#">Terms</a>]

# %%
print(soup.find('a'))
# Out:
# <a class="navbar-brand" href="/"><img alt="My image" class="brandLogo" src="/static/common/img/photo.png"/></a>

# %%
print(soup.find('p')['class'])
# Out:
# ['lead', 'text-muted']

# %%
print(soup.find('p').get_text())
# Out:
# Confused on which course to take? I have got you covered. Browse courses and find out
#             the best course for you. Its free!Code With Harry is my attempt to teach basics and those coding
#             techniques to people in short time which took me ages to learn.

# %%
all_links= set()
anchors=soup.find_all('a')
#print(anchors)
for link in anchors:
    if(link.get('href')!="#"):
        all_links.add(link.get('href'))
print(all_links)
# Out:
# {'/', '/contact', '/blog', '/videos'}

# %%
import requests
from bs4 import BeautifulSoup
from textblob import TextBlob

url = 'https://www.ebay.fr/'
french = []
english = []
r = requests.get(url)
c = r.content
soup = BeautifulSoup(c)
for li in soup.find_all('span'):
    french.append(li.text)

Frenchstr = ''.join(french)
blob = TextBlob(Frenchstr)
print(Frenchstr)
Englishstr = blob.translate(to="EN")
print('------------------------------------------------')
print(Englishstr)
# Out:
# Chargement en cours...Chargement en cours...Un problème est survenu. Pour en savoir plus, affichez le panier.AccueilTop catégoriesTop catégoriesAutres catégoriesTop catégoriesAutres catégoriesTop catégoriesAutres catégoriesTop catégoriesAutres catégoriesTop catégoriesAutres catégoriesTop catégoriesAutres catégoriesTop catégoriesAutres catégoriesTop catégoriesAutres catégoriesTop catégoriesAutres catégoriesPlus Bannière de la galerie 1/4Bannière de la galerie 1/4Démarrez sur les chapeaux de rouesLes essentiels pour prendre la route en toute sérénité - Livraison gratuite* Offre valable jusqu’au 15/07. Voir conditionsCommandez vos pneus et leur montage sur eBayEt bénéficiez de 15%* de remise sur le montage - Code PNEUFV15* Valable jusqu'au 30/06. Voir conditions.Vente Flash Philips jusqu’à -50%Bons Plans irrésistibles jusqu’au 24 juin seulement ! - Livraison gratuite* Prix de vente constatés et stocks limités.Faites-vous plaisir sans attendre5€* sur une sélection de produits en livraiso
# ...

# %%
import textblob
